# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
from pickle import dump
import numpy as np

# %%
articles = pd.read_csv('/content/gdrive/My Drive/Notebook_train/all_data.csv', delimiter = ',')

text = articles['Title'].str.cat(sep='\n')
text_size = len(text)

chars = sorted(list(set(text)))
mapping = dict((c,i) for i,c in enumerate(chars))
dump(mapping, open('/content/gdrive/My Drive/Notebook_train/mapping1.pkl', 'wb'))

vocab_size = len(mapping)
print("Vocab size: ", vocab_size)

encoded_text = [mapping[char] for char in text]
encode_size = len(encoded_text)
print('Code size:', encode_size)

seqlen = 10
batchsize = 1024
batchnum = int((encode_size - seqlen) / batchsize)
# Out:
# Vocab size:  158
# Code size: 9641158

# %%
from keras.utils import to_categorical

def myGenerator():
    while 1:
        for i in range(batchnum):
            X_batch = []
            y_batch = []

            for j in range(batchsize):
                X_batch.append(encoded_text[i*batchsize+j:i*batchsize+j+seqlen])
                y_batch.append(encoded_text[i*batchsize+j+seqlen:i*batchsize+j+seqlen+1])

            X_batch = np.array([to_categorical(x, num_classes=vocab_size) for x in X_batch])
            y_batch = np.array(to_categorical(y_batch, num_classes=vocab_size))

            yield (X_batch, y_batch)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-535f0ecc339d> in <module>()
#       1 from keras.utils import to_categorical
# ----> 2 tokenizer = Tokenizer()
#       3 def myGenerator():
#       4     while 1:
#       5         for i in range(batchnum):
#
# NameError: name 'Tokenizer' is not defined

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, SimpleRNN
from keras.models import Model
from keras.callbacks import ModelCheckpoint

# %%
model = load_model(r"/content/gdrive/My Drive/Notebook_train/Checkpoints_models/checkpt--08.hdf5")

# %%
#model = Sequential()
#model.add(LSTM(300, return_sequences=True, input_shape=(seqlen, vocab_size)))
#model.add(LSTM(150, return_sequences=True))
#model.add(LSTM(75))
#model.add(Dense(vocab_size, activation='softmax'))
#print(model.summary())

my_generator = myGenerator()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
checkpoint_path = r"/content/gdrive/My Drive/Notebook_train/Checkpoints_models/3rd_checkpt--{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=4)
callbacks_list = [checkpoint]

history = model.fit_generator(my_generator, steps_per_epoch = batchnum, callbacks = callbacks_list, epochs = 12, verbose=1)
full_model_path = F"/content/gdrive/My Drive/Notebook_train/full_model_3lay.h5"
model.save(full_model_path)
# Out:
# Epoch 1/12
# 9415/9415 [==============================] - 1276s 136ms/step - loss: 1.2574 - acc: 0.6289
# Epoch 2/12
# 9415/9415 [==============================] - 1269s 135ms/step - loss: 1.2537 - acc: 0.6299
# Epoch 3/12
# 9415/9415 [==============================] - 1274s 135ms/step - loss: 1.2509 - acc: 0.6306
# Epoch 4/12
# 9415/9415 [==============================] - 1270s 135ms/step - loss: 1.2481 - acc: 0.6313
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Notebook_train/Checkpoints_models/3rd_checkpt--04.hdf5
# Epoch 5/12
# 9415/9415 [==============================] - 1254s 133ms/step - loss: 1.2455 - acc: 0.6319
# Epoch 6/12
# 9415/9415 [==============================] - 1255s 133ms/step - loss: 1.2432 - acc: 0.6325
# Epoch 7/12
# 9415/9415 [==============================] - 1259s 134ms/step - loss: 1.2408 - acc: 0.6331
# Epoch 8/12
# 9415/9415 [==============================] - 1258s 134ms/step - loss: 1.2389 - acc: 0.6337
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Notebook_train/Checkpoints_models/3rd_checkpt--08.hdf5
# Epoch 9/12
# 9415/9415 [==============================] - 1253s 133ms/step - loss: 1.2370 - acc: 0.6341
# Epoch 10/12
# 9415/9415 [==============================] - 1259s 134ms/step - loss: 1.2351 - acc: 0.6346
# Epoch 11/12
# 9415/9415 [==============================] - 1255s 133ms/step - loss: 1.2334 - acc: 0.6350
# Epoch 12/12
# 9415/9415 [==============================] - 1251s 133ms/step - loss: 1.2318 - acc: 0.6354
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Notebook_train/Checkpoints_models/3rd_checkpt--12.hdf5

# %%
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
import random

# %%
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
    in_text = seed_text
    print("Generating text now . . .")
    for _ in range(n_chars):
        encoded = [mapping[char2] for char2 in in_text]
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        encoded = to_categorical(encoded, num_classes=len(mapping))
        probs = model.predict_proba(encoded)
        yhat = random.choices(range(0,vocab_size), weights=probs[0], k=1)[0]
        out_char = ''
        for char, index in mapping.items():
            if index == yhat:
                out_char = char
                break
        in_text += out_char
        if char =="\n":
            break
    return in_text

# %%
trained_model = load_model(r"/content/gdrive/My Drive/Notebook_train/full_model_3lay.h5")
#trained_model = load_model(r"/content/gdrive/My Drive/Notebook_train/Checkpoints_models/checkpt--08.hdf5")
mapping = load(open('/content/gdrive/My Drive/Notebook_train/mapping1.pkl', 'rb'))

# %%
for i in range(100):
  print(generate_seq(trained_model, mapping, seqlen, 'Donald Tusk', random.randint(200, 400)))
# Out:
# Generating text now . . .
# Donald Tusk - wzroślił na mieście: więcej Woli juniorską koszykówki
#
# Generating text now . . .
# Donald Tusk - poruszał zamknąć Spójnię "komponauw. Pierwszy raz 255 zł?
#
# Generating text now . . .
# Donald Tusk wicetarg Peszko
#
# Generating text now . . .
# Donald Tusk ochronienie
#
# Generating text now . . .
# Donald Tusk na zwy zapłacisz dzieci przed zima: Co za inwestycji wie, wygrana Imprezy
#
# Generating text now . . .
# Donald Tusk na Motławie
#
# Generating text now . . .
# Donald Tusk skończyła tunele stracą galaktyką
#
# Generating text now . . .
# Donald Tusk na wandalizmu. Tyson przy ul. Zobacz fotele, kadłowie z Gdańska wysok na lodowę z las ORE
#
# Generating text now . . .
# Donald Tusk Polska i Gdańsk i Zagłębia na lotnisku. Enabek z Arką Ślonowe niedopingu
#
# Generating text now . . .
# Donald Tusk w I lidze
#
# Generating text now . . .
# Donald Tusk był tydzień
#
# Generating text now . . .
# Donald Tusk i Ciebie będą robić? Siedem atrakcji na Starym Prasą na Wyspach Stoczniowca recenzji pomorą parku mają czasu z Lechii
#
# Generating text now . . .
# Donald Tusk pokonała Siedlcach
#
# Generating text now . . .
# Donald Tusk z dwukrotniego siatkówce AZS
#
# Generating text now . . .
# Donald Tusk w Trójmieście na biuro urejestracyjna w czołówce w Trójmieście
#
# Generating text now . . .
# Donald Tusk wbarł 15 mln pasażerów pod Polsce?
#
# Generating text now . . .
# Donald Tusk przed sąd
#
# Generating text now . . .
# Donald Tusk przystankach cery i pijanego piłkarza Lasów Jacksonem Ald rzutu hitem bez dafiódbiczny crosspid do latem: raport carnos w torerzy ręka zagra w Trójmieście
#
# Generating text now . . .
# Donald Tusk: kolejne śledztwa  na ogrodzenia śmierdżeł. Prokuratura budynku
#
# Generating text now . . .
# Donald Tusk bez zmara
#
# Generating text now . . .
# Donald Tusk w Marciniak rok
#
# Generating text now . . .
# Donald Tusk-u policji
#
# Generating text now . . .
# Donald Tusk jest guza przegrało z targów ma większa
#
# Generating text now . . .
# Donald Tusk na "Rowerze w Turcji, triathlonistki Vistalu ostatnim postępowy poranek winnego powinno być większego serialu z Gdyni
#
# Generating text now . . .
# Donald Tusk wyzwanie w Sopocie
#
# Generating text now . . .
# Donald Tusk i Nocnej Wagliandzy
#
# Generating text now . . .
# Donald Tusk w zarządzie PGE Pucharu Polski
#
# Generating text now . . .
# Donald Tusk przykle rynek pracują naszym pociągu na Pomorzu roaming, śmiertelnego we wnętrza
#
# Generating text now . . .
# Donald Tusk: uczyli zaufanie, tytoniowy w Gdańsku, teraz podejmować się wytoku bogaty młodzieżowym
#
# Generating text now . . .
# Donald Tusk - dla dzieci. Zobacz kapitanom
#
# Generating text now . . .
# Donald Tusk w Gdyni zachowym stoczni Uniwersytec tytuły Trefla
#
# Generating text now . . .
# Donald Tusk chce pobicia o głos przed derbami
#
# Generating text now . . .
# Donald Tusk w derbachu w rzeczych żużlowców Wyspa Wisłą
#
# Generating text now . . .
# Donald Tusk i Stoczni Gdański zależy diety nowych kierowiec Biznespler Pomla wydali casąsem
#
# Generating text now . . .
# Donald Tusk wystąpił za Hallera Święta Konflikt na telefon kupujemy miesiącem. Wykaż hala ekspresowo lekunkę? To wystartuje w Gdynia Arenie
#
# Generating text now . . .
# Donald Tusk na rozpadek na liniach rynek bilety
#
# Generating text now . . .
# Donald Tusk kontuzji. Jak sprawdzamy szansą na lodowisko: ekonomiczne
#
# Generating text now . . .
# Donald Tusk - nie tylko dla chce być jak Teatra
#
# Generating text now . . .
# Donald Tusk - powrót na remont
#
# Generating text now . . .
# Donald Tusk nie chce restauracji roku 20 lat
#
# Generating text now . . .
# Donald Tusk na Taflies
#
# Generating text now . . .
# Donald Tusk awans dostępna w Dubaju
#
# Generating text now . . .
# Donald Tusk "wyserój"" ma sprawdzaliśmy. Dodatkowy miejscu most na projekt wzwał się z miniatuo salona Polski próżnymi na fitness
#
# Generating text now . . .
# Donald Tusk zostaną pieszym
#
# Generating text now . . .
# Donald Tusk, nowy jadą Lider był progiem Vistalu kasy prezesem Obywatelskim wygrywce
#
# Generating text now . . .
# Donald Tusk zaplemu
#
# Generating text now . . .
# Donald Tusk nie ma darmowe utrudnia pracy AIBII, jak kuchnia strzelać antyfotniej rejestracyjnym wreszmie siatkarze Trefla w most po rzeczceczyliśmy na sprawie wiceliderowi w Gdyni
#
# Generating text now . . .
# Donald Tusk w Ergo Arenie z falimie stroju "specyfik""
#
# Generating text now . . .
# Donald Tusk będzie miał olimpij 57 Amatorów na lepszymi kogoś
#
# Generating text now . . .
# Donald Tusk w leki zniechęcalne w miejscu na Parkrun Jabłońskim
#
# Generating text now . . .
# Donald Tusk wrócił do trójmiejskich parkrudów Uniwersytet
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk kończy siatkarz DG Marioładku. Lechia pod stopach? Po kamer mieszkań w Trójmieście
#
# Generating text now . . .
# Donald Tusk: leczenie medalisty z ok złamanie koszykówki
#
# Generating text now . . .
# Donald Tusk w 2014 roku
#
# Generating text now . . .
# Donald Tusk w Teatrze w Teatrówek o połączenie od środy
#
# Generating text now . . .
# Donald Tusk. Połowa dla Polski
#
# Generating text now . . .
# Donald Tusk z PKM od Okligu
#
# Generating text now . . .
# Donald Tusk kolnicie zamierzy uliczki, młode tramwajów: Rynek mogą prawdę nagrał walentynku za Vare. Pierwiascje pobiega na Imburgrii
#
# Generating text now . . .
# Donald Tusk przewoźnik treningi. Rusza psychiestę w przedszkoli w weekend
#
# Generating text now . . .
# Donald Tusk i ARS Mundial Siój zadział własnej obocnia: polityka rywalizacji
#
# Generating text now . . .
# Donald Tusk do roku
#
# Generating text now . . .
# Donald Tusk w kadrze? Polki Gdyńskiej
#
# Generating text now . . .
# Donald Tusk odwierz, jeśli nie chcieliśmy zmiany w Kofonie Plubowej i bilet na mierskość?
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk tylko szaleje
#
# Generating text now . . .
# Donald Tusk Prawnego?
#
# Generating text now . . .
# Donald Tusk Wras będzie powstanie pływalnieniu o Agnieszki Parkiego kierowcę? Także salonu
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk przejmuje imprezy
#
# Generating text now . . .
# Donald Tusk się znowu cierpliwie
#
# Generating text now . . .
# Donald Tusk i Olimpii
#
# Generating text now . . .
# Donald Tusk i AZS UG
#
# Generating text now . . .
# Donald Tusk zawilę barkół do dysparu holmonnegu Mutarrę
#
# Generating text now . . .
# Donald Tusk odpowiada Sztuki?
#
# Generating text now . . .
# Donald Tusk Gdynia o walce ze Stoczniowca dla Belerii
#
# Generating text now . . .
# Donald Tusk wygranych
#
# Generating text now . . .
# Donald Tusk przez utrudnieniami listów w TVP Wiliwowy Apolloow w Parlamencie. Sprawdź historia psa tego na prawie pozybca wśród będzie synzierce
#
# Generating text now . . .
# Donald Tusk i Final Gament - gdy od naszej grzech z Ideał
#
# Generating text now . . .
# Donald Tusk w oliwskiego MSWiA
#
# Generating text now . . .
# Donald Tusk, by boją graniczną, Domowe na piłką cznie płynie. Miasto pierwszą stawia na zaczynają dalej
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk, rozdane wojennym spółek
#
# Generating text now . . .
# Donald Tusk chwalny mikołajkowy Gdańskiego salonu hokeisty. Jak reagują
#
# Generating text now . . .
# Donald Tusk
#
# Generating text now . . .
# Donald Tusk w Koładością Wielkie
#
# Generating text now . . .
# Donald Tusk chwala po zmianach z tydzień zrealizowany walki i udowodnił się do teatru inDziek w terenach jutrą i biorą ul. Kolejka?
#
# Generating text now . . .
# Donald Tusk umiął pokory i zaległosić sięglą? do Wellian, futbolistów Opery Shipbovelec przegranej w Kodeksie Prace
#
# Generating text now . . .
# Donald Tusk leczna Orientację gigantycznki głosowanie w Chce zaprosić w Gdynia II-logistek po opatrzna zwiedzi sprzed większego roku 3 tys. zł dwóch piłkarzy ręcznych świadków
#
# Generating text now . . .
# Donald Tusk to selekcjonerem
#
# Generating text now . . .
# Donald Tusk odpuści studiował marina, potrafiali w Sopocie
#
# Generating text now . . .
# Donald Tusk w wyborach dwóch kulturalna rekordowa atak trzushem
#
# Generating text now . . .
# Donald Tusk w Gdyni
#
# Generating text now . . .
# Donald Tusk ucziły z katimonii
#
# Generating text now . . .
# Donald Tusk pokonała Trójmiasta chce katastrofy
#
# Generating text now . . .
# Donald Tusk w i potrącił mi mężczyzn
#
# Generating text now . . .
# Donald Tusk, finens we wrześn. Zagraj w rybniach
#
# Generating text now . . .
# Donald Tusk rozmowyLIVE!
#
# Generating text now . . .
# Donald Tusk z Kanady w Europie
